# %% [markdown]
# ## Project Proposal : Influenza Like Illness Activity over the years

# %% [markdown]
# ## Problem Statement:
# Flu or Influenza is a common illness during fall and winter. I am curious to see if we are seeing an increase in Influenza cases in the past 21 years(1997 - 2018). The motivation for this analysis is that, every year we hear all the advertiserment about getting flu vaccines. There has been studies on and off on the effect of the vaccines and their impact on flu. I wanted to draw a trend of the Influenza like illnesses reported and see if I am able to see a decrease in these reported illness over time as a ratio of the total population and also if the trend is similar across age groups. I would like to use this analysis result and compare with all the publications around the effectiveness of influenza vaccine.
#
# According to National Vaccine Information Center, US has been prescribing vaccines on and off for more than 80 years. 1976 was the first mass production of the vaccine, though it did not turn out to be a success due to 3 death reported from taking vaccine. Per NVIC, "Seasonal flu vaccine production continued(even with the reported death's) and, in 1978, the first trivalent influenza vaccine was licensed for use in the U.S. after scientists identified two different influenza A strains circulating simultaneously". The
# https://www.nvic.org/vaccines-and-diseases/Influenza/vaccine-history.aspx
#
# In 1984, the CDC recommended annual flu shots for high risk individuals, which included adults over the age of 65; any person with a chronic illness or a metabolic disorder; persons living in nursing homes or other long term care facilities; and health care personnel. At that time, pregnancy was not considered to be a high risk factor for severe illness or complications from influenza. The 1984 ACIP committee stated, “Pregnancy has not been demonstrated to be a risk factor for severe influenza infection, except in the largest pandemics of 1918-1919 and 1957-1958"
# CDC Recommendation of the Immunization Practices Advisory Committee (ACIP) Prevention and Control of Influenza MMWR May 18, 1984; 33(19).
#
# I would like to collate all the information on all the research which was done on vaccines effect and then also using the CDC data on Influenza like illnesses to understand if there is a decrease or increase over the years.
#
#
# ## Data Used:
# I will be using data from Harvard dataverse data https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/ZJZM4F; specifically the file called ILINet.csv as well as also enhance it with data from Center for Disease Control
#
# CDC publish weekly unweighted Influenza-like Illness (ILI) activity level (gis.cdc.gov/grasp/fluview/fluportaldashboard.html).
# CDC updates this data as weeks progress as more data is gathered from participating clinics, hence I have only used data till 2018 as 2019 Flu season is still in progress.
#
# Data contains the following information
# ![Capture.PNG](attachment:Capture.PNG)
#
#
# ### Additional information from the CDC Help page on the data collection methodology
#
# https://gis.cdc.gov/grasp/fluview/FluViewPhase2QuickReferenceGuide.pdf)
#
# ##### Outpatient Illness Surveillance
# Information on patient visits to health care providers for
# influenza-like illness is collected through the U.S. Outpatient Influenza-like Illness
# Surveillance Network (ILINet). ILINet consists of approximately 3,200 outpatient healthcare
# providers in all 50 states, Puerto Rico, the District of Columbia and the U.S. Virgin Islands
# reporting over 36 million patient visits each year. Each week, approximately 2,000 outpatient
# healthcare providers around the country report data to CDC on the total number of patients
# seen and the number of those patients with influenza-like illness (ILI) by age group (0-4 years,
# 5-24 years, 25-49 years, 50-64 years, and ≥ 65 years). For this system, ILI is defined as fever
# (temperature of 100°F [37.8°C] or greater) and a cough and/or a sore throat in the absence of a
# known cause other than influenza. Sites with electronic records use an equivalent definition as
# determined by state public health authorities.
#
# ##### ILI baselines:
# The percentage of patient visits to healthcare providers for ILI reported each week is
# weighted on the basis of state population. This percentage is compared each week
# with the national baseline. The baseline is developed by calculating the mean
# percentage of patient visits for ILI during non-influenza weeks for the previous three
# seasons and adding two standard deviations. Due to wide variability in regional level
# data, it is not appropriate to apply the national baseline to regional data; therefore,
# region-specific baselines are calculated. Likewise, state or jurisdiction level data
# should not be compared to the national or regional baseline. Because
# state/jurisdiction level data may flucuate more from week to week depending on the
# providers that have reported, an alternate analysis is performed that compares the
# weekly percent of visits due to ILI to a baseline that is adjusted each week based on
# which sites within each jurisdiction provide data. For information regarding state and
# jurisdiction level data analysis please see
# (https://gis.cdc.gov/grasp/fluview/main.html).
#
# There is missing data till 1998 for 20 weeks. While running the analysis I will start from 1999 or use appropriate data cleansing techniques.
#
#
# ## Research Questions:
# #### Research Question1:
# Is there an increase in Influenza Like Illnesses over the course of the past 21 years?
#
# #### Research Question 2
# Are all age groups showing a similar behaviour over the years with respect to influenza like illnesses.
#
# #### Research Question 3:
# If there is an Increase or stays neutral how did vaccines influence in reducing this illness.
#
# ## Related Work:
#
# There is a lot of analysis and statistics around Influenza like illnesses and vaccine effects on the Ilness. I plan to leverage the work which has been already done for my Research Question #3 as I do not have data to conduct the analysis myself. I will read through all the available research on this topic and provide my summary and view point. I will not be able to do the analysis for #3 research question. CDC is the public source which has done the most investigations with respect to influenza.
#
# ## Methodology
# I plan to do ANOVA analysis for identifying the difference between different age groups. I will run a correlation study to understand the increase or decrease in influenza like illnesses over a period of time. The data is already available in a clean manner from CDC, the question which I would need to decide is what would be the benchmark for comaprision of the growth. Currently I am thinking of going with 1990 as the baselin year as that is the year we have the clean data to start with and compare again 2018.
#
# I will be using Python for most of the analysis, though will be using excel for some of the charts which are easier for me to do through excel.
#
# The analysis related to reading all of the research associated with vaccines and their effect on reducing Influenza is going to be comprehensive reading of all the material. Some of the sources where I will be gathering the information is mentioned below, while reading through these if i find additional sources I will be going through them as well
#
# ### Resources:
#
# 1. CDC. Influenza. Epidemiology and Prevention of Vaccine-Preventable Diseases (The Pink Book). 13th ed. 2015.
# 2. Biondi E.A , Aligne A.C. Flu Vaccine for All: A Critical Look at the Evidence Medscape Pediatrics Dec. 21, 2015.
# 3. 15 Hannoun C. The Evolving History of Influenza Viruses and Influenza Vaccines. Expert Rev Vaccines 2013;12(9):1085-1094.
# 4. CDC Using Live, Attenuated Influenza Vaccine for Prevention and Control of Influenza: Supplemental Recommendations of the Advisory Committee on Immunization Practices (ACIP) MMWR Sept. 26, 2003, 52(RR13);1-8
# 5. Mallory RM, Yi T, Ambrose CS. Shedding of Ann Arbor strain live attenuated influenza vaccine virus in children 6-59 months of age. Vaccine 2011; 29(26): 4322-4327.
# 6. The White House Press Briefing On Swine Influenza. Apr. 26, 2009.
# 7. Stobbe M. Ouch! Flu spray fails again, panel urges shot instead. Associated Press June 22, 2016.
# 8. CDC Recommendation of the Immunization Practices Advisory Committee (ACIP) Prevention and Control of Influenza MMWR May 18, 1984; 33(19).
# 9. Fisher BL. Vaccination During Pregnancy: Is It Safe? National Vaccine Information Center Nov. 9, 2013.
# 10. CDC Prevention and Control of Influenza: Recommendations of the Advisory Committee on Immunization Practices (ACIP). MMWR May 28, 2004; 53(RR06);1-40.
# 11. CDC Past Seasons Vaccine Effectiveness Estimates Apr. 5, 2019
# 12. Demicheli V, Jefferson T et al. Vaccines for preventing influenza in healthy adults. Cochrane Database of Systematic Reviews. Feb 1, 2018
