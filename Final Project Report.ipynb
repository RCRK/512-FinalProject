# %% [markdown]
# # A6 Final Project Report : Influenza Like Illness Activity over the years

# %% [markdown]
# # Introduction:
# Flu or Influenza is a common illness during fall and winter. I am curious to see if we are seeing an increase in Influenza cases in the past 19 years(1997 - 2016). The motivation for this analysis is that, every year we are bombarded by the advertiserment about getting flu vaccines. There have been studies on and off on the effect of the vaccines and their impact on flu. I wanted to draw a trend of the Influenza like illnesses reported and see if I am able to see a decrease in the rate of these reported illness over time. Also if the rate of these reported illnesses is similar across age groups.
#
# According to National Vaccine Information Center(NVIC), US has been prescribing vaccines on and off for more than 80 years. 1976 was the first mass production of the vaccine, though it did not turn out to be a success. First vaccine was developed in 1938 per NVIC data, since then we have had numorous versions of the vaccines and several delivery methods as well. As the influenza vaccine market expanded, so did recommendations for use by the Center for Disease Control's (CDC) Advisory Committee on Immunization Practices (ACIP).
#
# In 1984,  CDC recommended annual flu shots for high risk individuals, which included adults over the age of 65; any person with a chronic illness or a metabolic disorder; persons living in nursing homes or other long term care facilities; and health care personnel.Currently CDC recommends every one over the age of 6 months to take a flu vaccine every year. There are several analysis and research which is done in this area, this analysis is for anyone who wants a summary of Influenza like Illness and their trends.
#
# # Background and Related Work:
# There is a lot of work in this space, especially CDC has been doing a lot more analysis since early 2000's. As there have been research which said that taking a vaccine was helpful and similarly other analysis which said taking a vaccine did not make any difference. Cochrane Systematic Review in 2018 mentionined that they did not find any evidence of an association between influenza vaccination and serious adverse events in the comparative studies they researched. While another analysis showed that there is an effect of the vaccine compared to the control group. https://doi.org/10.1371/journal.pone.0023085
#
# I would leverage the work done by the various researchers as well as the data provided by CDC to analyze and help with answering the following research questions:
#
# #### Research Question1:
# Is there an increase in Influenza Like Illnesses over the course of the past 21 years?
#
# #### Research Question 2
# Are all age groups showing a similar behaviour over the years with respect to influenza like illnesses.
#
# #### Research Question 3:
# If there is an Increase or stays neutral how did vaccines influence in reducing this illness.
#
#
# #### Data Used:
# The data is collected from Harvard dataverse data https://dataverse.harvard.edu/dataset.xhtml?persistentId=doi:10.7910/DVN/ZJZM4F; specifically the file called ILINet.csv as well as also enhance it with data from Center for Disease Control
#
# CDC publish weekly unweighted Influenza-like Illness (ILI) activity level (gis.cdc.gov/grasp/fluview/fluportaldashboard.html).
# CDC updates this data as weeks progress as more data is gathered from participating clinics, hence I have only used data till 2018 as 2019 Flu season is still in progress.
#
# Data contains the following information
# ![Capture.PNG](attachment:Capture.PNG)
#
#
# ### Additional information from the CDC Help page on the data collection methodology
#
# https://gis.cdc.gov/grasp/fluview/FluViewPhase2QuickReferenceGuide.pdf)
#
# ##### Outpatient Illness Surveillance
# Information on patient visits to health care providers for influenza-like illness is collected through the U.S. Outpatient Influenza-like Illness Surveillance Network (ILINet). ILINet consists of approximately 3,200 outpatient healthcare providers in all 50 states, Puerto Rico, the District of Columbia and the U.S. Virgin Islands reporting over 36 million patient visits each year. Each week, approximately 2,000 outpatient healthcare providers around the country report data to CDC on the total number of patients seen and the number of those patients with influenza-like illness (ILI) by age group (0-4 years, 5-24 years, 25-49 years, 50-64 years, and ≥ 65 years). For this system, ILI is defined as fever (temperature of 100°F [37.8°C] or greater) and a cough and/or a sore throat in the absence of a known cause other than influenza. Sites with electronic records use an equivalent definition as determined by state public health authorities.
#
# ##### ILI baselines:
# The percentage of patient visits to healthcare providers for ILI reported each week is weighted on the basis of state population. This percentage is compared each week with the national baseline. The baseline is developed by calculating the mean
# percentage of patient visits for ILI during non-influenza weeks for the previous three seasons and adding two standard deviations. Due to wide variability in regional level data, it is not appropriate to apply the national baseline to regional data; therefore, region-specific baselines are calculated. Likewise, state or jurisdiction level data should not be compared to the national or regional baseline. Because state/jurisdiction level data may flucuate more from week to week depending on the
# providers that have reported, an alternate analysis is performed that compares the weekly percent of visits due to ILI to a baseline that is adjusted each week based on which sites within each jurisdiction provide data. For information regarding state and jurisdiction level data analysis please see (https://gis.cdc.gov/grasp/fluview/main.html).
#
# There is missing data till 1998 for 20 weeks. While running the analysis I will start from 1999 or use appropriate data cleansing techniques.
#
#
#
# ## Methodology:
# Initially I was planning on using the data point to do ANOVA study. But I realized that I only had <20 data points per year and I would have been over analysing it by leveraging various technique. Hence I settledand seeing the trends over these 19 years and also then leveraging all of the analysis and thick data available on this subject. The data is already available in a clean manner from CDC, I was planning on using a baseline and then a comparision to that baseline but later after looking at the data and analysing I decided to keep it simple and leverage the already done analysis. The Final Data which was used is in the excel which is uploaded to the share as well as linked here.
#
# The data can be viewed in Picture 1 below
#
#
# ## Findings:
# Interesting findings from the Analysis:
# 1. Over the 19 years of data looked at we see that the rate of Influenza like ilness (Influenza like illness (ILI) reported divided by the total number of patients) is on average 2.2% across all the years. This does look pretty consistent across years. The standard deviation of this rate is "0.33%". There were few years when this rate dropped a little and some years the rate is higher than even the average rate.  Picture 2 below shows the trended data. This is also available in the excel in the share
#
# 2. Across age groups as well we see a consistent trend of Influenza Like Ilnesses. There is no downward trend of influenza like ilness even though we have seen above that the vaccine advertisements and usage has increased per all published literature.Picture 2 shows the chart by age group.
#
# Then the question is what is happening here:
# When we review if there is an increase in vaccine consumption based on the CDC pulished data (as seen in picture 3 below) we see that the vaccine doses has significantly increased over the years and currently we are at 160million does of vaccine per flu season. Then even after the vaccine doses have increased why the ILI trends stay similar across the Years?
#
# The answer to that comes from CDC which states that in general, current flu vaccines tend to work better against influenza B and influenza A(H1N1) viruses and offer lower protection against influenza A(H3N2) viruses. CDC measures if a vaccine is working or not by measuring the Effectiveness(VE) of a vaccine. Though this effectiveness varies Year over year, CDC mentions that flu vaccination reduces the risk of flu illness by between 40% and 60% among the overall population during seasons when most circulating flu viruses are well-matched to the flu vaccine. As seen in Picture 4 below the effectiveness varies by season and is not higher than 60% in the past 10 years.
#
# The Effectiveness of a vaccine is dependent on multiple factors as below Per CDC (https://www.cdc.gov/flu/prevent/vaccineeffect.htm:
# 1) Characteristics of the person being vaccinated (such as their age and health)
# 2) The similarity or “match” between the flu viruses the flu vaccine is designed to protect against and the flu viruses spreading in the community
# Other factors Include
# 3) Characteristics of the person being vaccinated
# 4) What influenza viruses are circulating that season
# 5) Potentially, which type of flu vaccine was used
#
# So per CDC it is not a simple to answer why the effectiveness of the vaccine in a given year is low or why a individual even after getting a vaccine got the flu. It is a confluence of factors which determine if the vaccine will be effective or not. CDC though publishes every year the effectiveness score at the aggregate level as well as per age group. The details can be found here https://www.cdc.gov/flu/vaccines-work/2018-2019.html
#
# Another point which CDC makes is that even though if the effectiveness of a vaccine is less than 60% there are additional benefits we are getting in the society for taking the vaccine. Taking a flu vaccine is reducing the burden of flu to the society. The burden reflects the cost averted to the society as there are people who are vaccinated and hence u illnesses, flu hospitalizations, and flu deaths are averted. It is a hard problem to solve but they extra polate based on the coverage of vaccines and the effecitiveness.
#
# ## Discussions:
# Though this project was not heavy on analytics it was a research project collating various sources of information to form a opinion on Vaccines. My research was focussed on the effectiveness of the vaccines and the reported illness but I did not research on the side effects of flu vaccine. There is enough research which shows that there isnt no effect vs there is an effect. But without any information on the side effects possible of the flu vaccine I have reached a conclusion that having a flu vaccine is better for the society rather than not having it especially for the high risk individuals.
#
# Why the trends are still similar is not answerable with the analysis I have done. There is no downward trend it is pretty stable. Does it show that we need more vaccinations to be done or we have more strains of viruses whihc are not able to be captured through the vaccine? These could be follow up question specifically on why the rate has not shifted down even with so much research on this topic and it is now greater than $3 - $6 Billion per year. Are there side effects for flu vaccines. Have not seen any research by CDC would be something to follow up on.
#
#
# #####  Limitations of the analysis:
# I have not done any normalizations based on the population size, advancements in technology, awareness of flu, gender or location based. So all these variables could play a role, if people are more aware and less patient about being sick even for a day there is a chance of going to the hospital while is it possible that couple of decades ago people expected that the sickness automatically reduced after couple of days and did not go to the doctors. All these variables could have effected the ILI rate and I did not have time nor the resources to do the analysis accurately.
#
#
# ## Conclusions:
#
# I started the analysis with the below three research questions:
#
# 1. Is there an increase in Influenza Like Illnesses over the course of the past 19 years?
# 2. Are all age groups showing a similar behaviour over the years with respect to influenza like illnesses.
# 3. If there is an Increase or stays neutral how did vaccines influence in reducing this illness.
#
# So my conclusion from the analysis is that the rate of Influenza Like Ilness over the flue season years has not decreased. It has steady steady. Also across the age groups it has been steady over the years. I am a little surprised by the results as my expectation was that the rate would have decreased over the years with the increase in vaccine coverage.
#
# Coming to the third question on the influence of vaccines it was eye opening for me in reading all the research about the effectiveness of the vaccines. Given that I did not see much change in the rate of Influenza like Illness and the increase in vaccine consumption it was more baffling. The research helped me understand the various other aspects associated with the effectiveness of a vaccine and to me I think there is going to be a lot more reasearch on this topic. There is a booming business being built on flu vaccine and as this industry grows there will be more debate on pros and cons.
#
# This project has leveraged several of the Human Centered Data Science topics, some of the key ones which came into picture was:
# 1. This project was not a black and white analysis. It was not based on just quantitative research. This made the project interesting as well as challenging. It makes it clear that only information from well documented research is valid. There are several websites which talk about the worst case of vaccine use. If as a educated person I was challenged in identifying valid sites vs not credible content it worries me on how an average person could seperate through these. Thick Data usage is hard!
# 2. The question we ask is also important. CDC has published so much information but for an average person trying to identify how to navigate the flu vaccine world a much simpler summary would have been great. This ties to simple design and summary needed for any data reports.
# 3. Navigating through all this data it is important to be able to make the scores interpretable, the burden removal from community is a challenging number for folks to understand. The effectiveness of a vaccine was much more easily understood.

# %%
# Picture 1
from PIL import Image
display(Image.open("Data.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1107x461 at 0x5C33A10>

# %%
# Picture 2
from PIL import Image
display(Image.open("charts.png"))
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1022x304 at 0x5C332B0>

# %%
# Picture 3
from PIL import Image
display(Image.open("VaccineDoses.png"))
## https://www.cdc.gov/flu/prevent/vaccine-supply-historical.htm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=980x526 at 0xDB8E70>

# %%
# Picture 4
from PIL import Image
display(Image.open("Effectiveness.png"))
## https://www.cdc.gov/flu/professionals/vaccination/effectiveness-studies.htm
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=967x376 at 0xDCF510>

# %% [markdown]
# ## Resources/ References:
#
# 1. CDC. Influenza. Epidemiology and Prevention of Vaccine-Preventable Diseases (The Pink Book). 13th ed. 2015.
# 2. Biondi E.A , Aligne A.C. Flu Vaccine for All: A Critical Look at the Evidence Medscape Pediatrics Dec. 21, 2015.
# 3. 15 Hannoun C. The Evolving History of Influenza Viruses and Influenza Vaccines. Expert Rev Vaccines 2013;12(9):1085-1094.
# 4. CDC Using Live, Attenuated Influenza Vaccine for Prevention and Control of Influenza: Supplemental Recommendations of the Advisory Committee on Immunization Practices (ACIP) MMWR Sept. 26, 2003, 52(RR13);1-8
# 5. Mallory RM, Yi T, Ambrose CS. Shedding of Ann Arbor strain live attenuated influenza vaccine virus in children 6-59 months of age. Vaccine 2011; 29(26): 4322-4327.
# 6. Stobbe M. Ouch! Flu spray fails again, panel urges shot instead. Associated Press June 22, 2016.
# 7. CDC Recommendation of the Immunization Practices Advisory Committee (ACIP) Prevention and Control of Influenza MMWR May 18, 1984; 33(19).
# 9. CDC Prevention and Control of Influenza: Recommendations of the Advisory Committee on Immunization Practices (ACIP). MMWR May 28, 2004; 53(RR06);1-40.
# 10. CDC Past Seasons Vaccine Effectiveness Estimates Apr. 5, 2019
# 11. Demicheli V, Jefferson T et al. Vaccines for preventing influenza in healthy adults. Cochrane Database of Systematic Reviews. Feb 1, 2018
# 12. https://www.cdc.gov/flu/prevent/vaccinations.htm
# 13. https://www.nvic.org/vaccines-and-diseases/Influenza/vaccine-history.aspx
# 14. https://www.cochranelibrary.com/cdsr/doi/10.1002/14651858.CD001269.pub6/full
# 15. https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0023085
# 16. https://www.cdc.gov/flu/prevent/vaccine-supply-historical.htm
# 17. https://www.cdc.gov/flu/prevent/vaccineeffect.htm
# 18. https://needtoknow.news/2019/11/the-6-billion-influenza-vaccine-industry-produces-flu-shots-that-can-cause-harm-and-have-low-rate-of-efficiency/
